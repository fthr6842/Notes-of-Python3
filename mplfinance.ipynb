# %%
import mplfinance as mpf
import yfinance as yf

# %%
data = yf.download("2330.tw", "2023-12-01", "2023-12-31")
data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#              Open   High    Low  Close   Adj Close    Volume
# Date
# 2023-12-01  573.0  579.0  573.0  579.0  573.312378  28051165
# 2023-12-04  582.0  582.0  571.0  574.0  568.361450  26847171
# 2023-12-05  571.0  572.0  567.0  570.0  564.400757  22229723
# 2023-12-06  568.0  575.0  568.0  570.0  564.400757  21518089
# 2023-12-07  570.0  573.0  566.0  566.0  560.440063  20840397
# 2023-12-08  574.0  577.0  570.0  570.0  564.400757  33507214
# 2023-12-11  572.0  575.0  570.0  574.0  568.361450  27378610
# 2023-12-12  580.0  581.0  575.0  578.0  572.322205  29403010
# 2023-12-13  576.0  579.0  576.0  577.0  571.331970  22977731
# 2023-12-14  581.0  582.0  579.0  582.0  579.294800  39409958
# 2023-12-15  585.0  586.0  580.0  585.0  582.280884  54323262
# 2023-12-18  579.0  585.0  577.0  585.0  582.280884  26122277
# 2023-12-19  588.0  588.0  580.0  585.0  582.280884  28254292
# ...

# %%
mpf.plot(data, type='candle', volume=True)

# %% [markdown]
# mpf.plot(df, type='candle', volume=True, mav= (tuple) )
# //df: 資料
# //type: 線圖型態。
#     'candle'--K線, 'line'--折線圖, 'renko'--磚形圖, 'pnf'--點數圖, 'ohlc'--美國線
# //volume: 在底部加入成交量
#     True or False
# //mav: 加入移動平均線(m, n, k, ...)
