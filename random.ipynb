# %%
import random

# %%
random.seed(1)

# %% [markdown]
# #### a: NoneType、int、float、str、bytes、bytearray

# %%
random.getstate()
# Out:
# (3,
#  (2147483648,
#   163610392,
#   3414454684,
#   213706556,
#   4107842212,
#   2345084137,
#   1370141154,
#   308032203,
#   1333762497,
#   62788148,
#   3897778028,
#   747877958,
#   1467715487,
#   3456091536,
#   2761063683,
#   1618744790,
#   1478419815,
#   1764113510,
#   846282508,
#   2723886408,
#   4169581479,
#   1502702845,
#   2646586442,
#   2469253028,
#   2959591262,
#   4098450497,
#   884511481,
#   335884721,
#   3599209546,
#   513139374,
#   3325056467,
#   728657986,
#   4258769976,
#   1345736399,
#   2025918085,
#   3316918730,
#   2943630414,
#   2227403036,
#   2570027851,
#   3647123330,
#   1428539568,
#   3871201705,
#   1751794003,
#   270064251,
#   1795576567,
#   1369598507,
#   618682879,
#   2451807245,
#   529121120,
#   3890334672,
#   1711572734,
#   3489061444,
#   651351815,
#   4134812839,
#   69921281,
#   166843555,
#   3639104358,
#   1220147039,
#   1949863666,
#   1735631448,
#   1274775129,
#   2568486724,
#   1135749407,
# ...

# %% [markdown]
# #### 回傳一個物件，捕獲產生器的當前內部狀態

# %%
random.setstate()

# %% [markdown]
# #### 從之前對getstate()的呼叫中獲得，並且以setstate()將產生器的內部狀態恢復到呼叫getstate()時的狀態。

# %%
random.getrandbits(3)
# Out:
# 4

# %% [markdown]
# #### 產生n個隨機位元組

# %%
random.random()
# Out:
# 0.8474337369372327

# %% [markdown]
# #### 傳回一個[0, 1)的數

# %%
random.randint(0, 5)
# Out:
# 2

# %% [markdown]
# #### 傳回一個介於整數a, b之間的整數(包含a, b)

# %%
random.uniform(0, 1)
# Out:
# 0.11791870367106105

# %% [markdown]
# #### 傳回一個a, b之間的浮點數(a, b可互換)

# %%
data = [90, 86, 56, 77, 63]
random.choice(data)
# Out:
# 90

# %% [markdown]
# #### 傳回元素E中的一個value(E可為字串(string)、串列(list)、元組(tuple))
# #### 不適用於dict, dict_items()

# %%
#random.randrange(stop)

# %% [markdown]
# #### random.randrange(start, stop, step)--傳回a+n*c<=b(隨機步數計算)，c的預設值為1

# %%
random.sample("test", 2)
# Out:
# ['t', 's']

# %% [markdown]
# #### E為字串、串列或是元組，N為<=len(E)整數。隨機傳回樣本群中、指定數量的隨機樣本

# %%
random.shuffle(data)
data
# Out:
# [77, 90, 86, 56, 63]

# %% [markdown]
# #### 重新指派串列data的順序

# %%
random.gauss(mu=0, sigma=1)
# Out:
# 0.20345118615345922

# %% [markdown]
# #### Normal Distribution pdf
